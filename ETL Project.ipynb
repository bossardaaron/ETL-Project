# %% [markdown]
# # Import Dependencies

# %%
import pandas as pd
from sqlalchemy import create_engine
import psycopg2

# %% [markdown]
# # Extract our data files and store in data frames

# %%
csv_file1 = "qgdpstate0519_3.csv"
gdp_by_state_df = pd.read_csv(csv_file1)
gdp_by_state_df.head()
# Out:
#   Table 1. Percent Change in Real Gross Domestic Product (GDP) by State and Region, 2017:Q1-2018:Q4  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                      United States
# 4                                       New England
#
#                             Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0  Seasonally adjusted at annual rates        NaN        NaN        NaN
# 1                                 2017        NaN        NaN        NaN
# 2                                   Q1         Q2         Q3         Q4
# 3                                  1.8        3.0        2.8        2.3
# 4                                  0.6        2.8        3.1       -0.5
#
#   Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8    Unnamed: 9  Unnamed: 10
# 0        NaN        NaN        NaN        NaN           NaN          NaN
# ...

# %%
csv_file2 = "personal_saving.csv"
personal_saving_df = pd.read_csv(csv_file2)
personal_saving_df.head()
# Out:
#   Table 1. Personal Income, by State and Region, 2017:Q4-2019:Q1  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                     United States
# 4                                       New England
#
#                                           Unnamed: 1  Unnamed: 2  Unnamed: 3  \
# 0  [Millions of dollars, seasonally adjusted at a...         NaN         NaN
# 1                                               2017        2018         NaN
# 2                                                 Q4         Q1r         Q2r
# 3                                         17,090,705  17,313,151  17,460,221
# 4                                            963,895     979,868     981,773
#
#    Unnamed: 4  Unnamed: 5  Unnamed: 6                              Unnamed: 7  \
# 0         NaN         NaN         NaN    [Seasonally adjusted at annual rate]
# ...

# %% [markdown]
# # Create new data with select columns

# %%
new_gdp_by_state_df = gdp_by_state_df[['Table 1. Percent Change in Real Gross Domestic Product (GDP) by State and Region, 2017:Q1-2018:Q4', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5']].copy()
new_gdp_by_state_df.head()
# Out:
#   Table 1. Percent Change in Real Gross Domestic Product (GDP) by State and Region, 2017:Q1-2018:Q4  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                      United States
# 4                                       New England
#
#   Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5
# 0        NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN       2018
# 2         Q2         Q3         Q4         Q1
# 3        3.0        2.8        2.3        2.2
# 4        2.8        3.1       -0.5        3.6

# %%
new_personal_saving_df = personal_saving_df[['Table 1. Personal Income, by State and Region, 2017:Q4-2019:Q1',  'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5']].copy()
new_personal_saving_df.head()
# Out:
#   Table 1. Personal Income, by State and Region, 2017:Q4-2019:Q1  Unnamed: 2  \
# 0                                                NaN                     NaN
# 1                                                NaN                    2018
# 2                                                NaN                     Q1r
# 3                                     United States               17,313,151
# 4                                       New England                  979,868
#
#    Unnamed: 3  Unnamed: 4  Unnamed: 5
# 0         NaN         NaN         NaN
# 1         NaN         NaN         NaN
# 2         Q2r         Q3r         Q4r
# 3  17,460,221  17,647,510  17,825,728
# 4     981,773     992,031     998,048

# %% [markdown]
# # Clean data frames

# %% [markdown]
# # Connect to local database

# %%
rds_connection_string = "<insert user name>:<insert password>@localhost:5432/customer_db"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %% [markdown]
# # Check for tables

# %%
engine.table_names()

# %% [markdown]
# # Confirm data has been added by querying the customer_name table

# %% [markdown]
# # Confirm data has been added by querying the customer_location table
